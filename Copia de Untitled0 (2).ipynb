# %% [markdown]
# # Introducción a la Innovación disruptiva
#
# ## Creación de bases de datos
#
# ![Image](
# https://media4.giphy.com/media/v1.Y2lkPTc5MGI3NjExNzRyNHZ1bDRxYndicHMyYnQ4Nnc0aDB1a3J0c2o3enI3cm9xM203dCZlcD12MV9pbnRlcm5hbF9naWZfYnlfaWQmY3Q9Zw/b4K0MfAZNLiQDqgYJN/giphy.gif)

# %%
top_startups = {
  "top_startups_2024": [
    {
      "rank": 1,
      "name": "OpenAI",
      "industry": "Artificial Intelligence",
      "valuation_usd_billions": 80,
      "headquarters": "San Francisco, USA",
      "key_products": ["ChatGPT", "GPT-4", "DALL-E"],
      "founders": ["Elon Musk", "Sam Altman", "Ilya Sutskever"],
      "year_founded": 2015
    },
    {
      "rank": 2,
      "name": "SpaceX",
      "industry": "Aerospace",
      "valuation_usd_billions": 150,
      "headquarters": "Hawthorne, USA",
      "key_products": ["Falcon Rockets", "Starlink", "Starship"],
      "founders": ["Elon Musk"],
      "year_founded": 2002
    },
    {
      "rank": 3,
      "name": "Stripe",
      "industry": "Fintech",
      "valuation_usd_billions": 65,
      "headquarters": "San Francisco, USA",
      "key_products": ["Payment Processing", "Stripe Connect"],
      "founders": ["Patrick Collison", "John Collison"],
      "year_founded": 2010
    },
    {
      "rank": 4,
      "name": "Canva",
      "industry": "Design Software",
      "valuation_usd_billions": 40,
      "headquarters": "Sydney, Australia",
      "key_products": ["Canva Design Platform", "Canva Pro"],
      "founders": ["Melanie Perkins", "Cliff Obrecht", "Cameron Adams"],
      "year_founded": 2012
    },
    {
      "rank": 5,
      "name": "Databricks",
      "industry": "Data & AI",
      "valuation_usd_billions": 43,
      "headquarters": "San Francisco, USA",
      "key_products": ["Databricks Lakehouse", "MLflow"],
      "founders": ["Ali Ghodsi", "Matei Zaharia", "Ion Stoica"],
      "year_founded": 2013
    },
    {
      "rank": 6,
      "name": "Discord",
      "industry": "Communication",
      "valuation_usd_billions": 15,
      "headquarters": "San Francisco, USA",
      "key_products": ["Discord App", "Nitro Subscription"],
      "founders": ["Jason Citron", "Stan Vishnevskiy"],
      "year_founded": 2015
    },
    {
      "rank": 7,
      "name": "Epic Games",
      "industry": "Gaming & Metaverse",
      "valuation_usd_billions": 32,
      "headquarters": "Cary, USA",
      "key_products": ["Unreal Engine", "Fortnite"],
      "founders": ["Tim Sweeney"],
      "year_founded": 1991
    },
    {
      "rank": 8,
      "name": "Rivian",
      "industry": "Electric Vehicles",
      "valuation_usd_billions": 25,
      "headquarters": "Irvine, USA",
      "key_products": ["R1T Truck", "R1S SUV"],
      "founders": ["RJ Scaringe"],
      "year_founded": 2009
    },
    {
      "rank": 9,
      "name": "ByteDance",
      "industry": "Social Media & AI",
      "valuation_usd_billions": 300,
      "headquarters": "Beijing, China",
      "key_products": ["TikTok", "Douyin"],
      "founders": ["Zhang Yiming"],
      "year_founded": 2012
    },
    {
      "rank": 10,
      "name": "Deel",
      "industry": "HR & Remote Work",
      "valuation_usd_billions": 12,
      "headquarters": "San Francisco, USA",
      "key_products": ["Global Payroll", "Contract Management"],
      "founders": ["Alex Bouaziz", "Shuo Wang"],
      "year_founded": 2018
    }
  ],
  "source": "Forbes, CB Insights (2024)",
  "note": "Valuations and rankings are approximate and subject to change."
}

# %%
EID_701 = {"Rodrigo":[21, "soltero", "Valeria",1.70], "Sam": [21, "soltera", "Blee", 1.67], "Luis": [20, "soltero", "angie", 1.65]}

# %%
EID_701.values()
# Out:
# dict_values([[21, 'soltero', 'Valeria', 1.7], [21, 'soltera', 'Blee', 1.67], [20, 'soltero', 'angie', 1.65]])

# %%
pd.DataFrame(EID_701)
# Out:
#    Rodrigo      Sam     Luis
# 0       21       21       20
# 1  soltero  soltera  soltero
# 2  Valeria     Blee    angie
# 3      1.7     1.67     1.65

# %%
# ¿Cuáles son los datos de Sam?
DF_701["Sam"]
# Out:
# 0         21
# 1    soltera
# 2       Blee
# 3       1.67
# Name: Sam, dtype: object

# %%
# ¿Cuáles son los datos de Sam?
DF_701["Sam"][0]
# Out:
# 21

# %%
top_startups.values()
# Out:
# dict_values([[{'rank': 1, 'name': 'OpenAI', 'industry': 'Artificial Intelligence', 'valuation_usd_billions': 80, 'headquarters': 'San Francisco, USA', 'key_products': ['ChatGPT', 'GPT-4', 'DALL-E'], 'founders': ['Elon Musk', 'Sam Altman', 'Ilya Sutskever'], 'year_founded': 2015}, {'rank': 2, 'name': 'SpaceX', 'industry': 'Aerospace', 'valuation_usd_billions': 150, 'headquarters': 'Hawthorne, USA', 'key_products': ['Falcon Rockets', 'Starlink', 'Starship'], 'founders': ['Elon Musk'], 'year_founded': 2002}, {'rank': 3, 'name': 'Stripe', 'industry': 'Fintech', 'valuation_usd_billions': 65, 'headquarters': 'San Francisco, USA', 'key_products': ['Payment Processing', 'Stripe Connect'], 'founders': ['Patrick Collison', 'John Collison'], 'year_founded': 2010}, {'rank': 4, 'name': 'Canva', 'industry': 'Design Software', 'valuation_usd_billions': 40, 'headquarters': 'Sydney, Australia', 'key_products': ['Canva Design Platform', 'Canva Pro'], 'founders': ['Melanie Perkins', 'Cliff Obrecht', 'Cameron Adams'], 'year_founded': 2012}, {'rank': 5, 'name': 'Databricks', 'industry': 'Data & AI', 'valuation_usd_billions': 43, 'headquarters': 'San Francisco, USA', 'key_products': ['Databricks Lakehouse', 'MLflow'], 'founders': ['Ali Ghodsi', 'Matei Zaharia', 'Ion Stoica'], 'year_founded': 2013}, {'rank': 6, 'name': 'Discord', 'industry': 'Communication', 'valuation_usd_billions': 15, 'headquarters': 'San Francisco, USA', 'key_products': ['Discord App', 'Nitro Subscription'], 'founders': ['Jason Citron', 'Stan Vishnevskiy'], 'year_founded': 2015}, {'rank': 7, 'name': 'Epic Games', 'industry': 'Gaming & Metaverse', 'valuation_usd_billions': 32, 'headquarters': 'Cary, USA', 'key_products': ['Unreal Engine', 'Fortnite'], 'founders': ['Tim Sweeney'], 'year_founded': 1991}, {'rank': 8, 'name': 'Rivian', 'industry': 'Electric Vehicles', 'valuation_usd_billions': 25, 'headquarters': 'Irvine, USA', 'key_products': ['R1T Truck', 'R1S SUV'], 'founders': ['RJ Scaringe'], 'year_founded': 2009}, {'rank': 9, 'name': 'ByteDance', 'industry': 'Social Media & AI', 'valuation_usd_billions': 300, 'headquarters': 'Beijing, China', 'key_products': ['TikTok', 'Douyin'], 'founders': ['Zhang Yiming'], 'year_founded': 2012}, {'rank': 10, 'name': 'Deel', 'industry': 'HR & Remote Work', 'valuation_usd_billions': 12, 'headquarters': 'San Francisco, USA', 'key_products': ['Global Payroll', 'Contract Management'], 'founders': ['Alex Bouaziz', 'Shuo Wang'], 'year_founded': 2018}], 'Forbes, CB Insights (2024)', 'Valuations and rankings are approximate and subject to change.'])
